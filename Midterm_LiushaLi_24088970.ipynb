# %%
import pandas as pd
import numpy as np
import json
import requests 
import matplotlib.pyplot as plt
import sqlite3

# %%
#Part 1

# %%
#1

# %%
df = pd.read_csv(r'data/EQR.csv')
df
# Out:
#             Date       High        Low       Open      Close     Volume  \
# 0     2017-11-13  70.250000  68.800003  69.150002  70.150002  1377500.0
# 1     2017-11-14  70.349998  69.570000  70.089996  69.980003  1520100.0
# 2     2017-11-15  70.089996  68.900002  69.970001  69.029999  1072900.0
# 3     2017-11-16  69.419998  68.529999  69.070000  69.220001  1025500.0
# 4     2017-11-17  69.300003  68.169998  68.980003  68.320000  1630400.0
# ...          ...        ...        ...        ...        ...        ...
# 1254  2022-11-07  61.740002  59.680000  61.740002  60.189999  2022600.0
# 1255  2022-11-08  60.830002  59.680000  60.619999  60.060001  1742200.0
# 1256  2022-11-09  60.349998  59.419998  60.080002  59.680000  2375400.0
# 1257  2022-11-10  64.040001  61.650002  61.650002  63.970001  2137300.0
# 1258  2022-11-11  64.529999  62.340000  64.180000  62.779999  2304800.0
#
#       Adj Close
# 0     60.831173
# 1     60.683773
# 2     59.859966
# 3     60.024731
# ...

# %%
df['Close']-df['Adj Close']
# Out:
# 0       9.318829
# 1       9.296230
# 2       9.170033
# 3       9.195271
# 4       9.075714
#           ...
# 1254    0.000000
# 1255    0.000000
# 1256    0.000000
# 1257    0.000000
# 1258    0.000000
# Length: 1259, dtype: float64

# %%
df2 = pd.read_csv(r'data/JKHY.csv')
df2
# Out:
#             Date        High         Low        Open       Close     Volume  \
# 0     2017-11-13  113.769997  112.709999  113.419998  112.849998   350700.0
# 1     2017-11-14  113.400002  112.830002  112.980003  113.099998   489100.0
# 2     2017-11-15  112.959999  111.879997  112.620003  112.339996   334900.0
# 3     2017-11-16  113.129997  112.019997  112.699997  112.190002   327700.0
# 4     2017-11-17  112.599998  111.370003  112.070000  112.080002   257500.0
# ...          ...         ...         ...         ...         ...        ...
# 1253  2022-11-04  182.009995  177.270004  180.990005  180.460007   626500.0
# 1254  2022-11-07  182.619995  180.190002  181.240005  181.850006   645500.0
# 1255  2022-11-08  184.149994  179.160004  182.389999  180.940002   721700.0
# 1256  2022-11-10  181.250000  173.960007  177.649994  175.750000  1009800.0
# 1257  2022-11-11  177.860001  172.649994  175.279999  174.490005   713200.0
#
#        Adj Close
# 0     108.251549
# 1     108.491348
# ...

# %%
df2['Close']-df2['Adj Close']
# Out:
# 0       4.598450
# 1       4.608650
# 2       4.577667
# 3       4.571556
# 4       4.567078
#           ...
# 1253    0.000000
# 1254    0.000000
# 1255    0.000000
# 1256    0.000000
# 1257    0.000000
# Length: 1258, dtype: float64

# %%
df3 = pd.read_csv(r'data/WYNN.csv')
df3
# Out:
#             Date        High         Low        Open       Close     Volume  \
# 0     2017-11-13  156.399994  153.520004  153.750000  155.240005  1282900.0
# 1     2017-11-14  155.270004  152.279999  154.539993  153.600006  1101200.0
# 2     2017-11-15  152.500000  150.009995  152.500000  151.619995  1191100.0
# 3     2017-11-16  154.300003  151.809998  152.000000  153.199997  1269900.0
# 4     2017-11-17  153.690002  151.979996  152.899994  152.279999   849600.0
# ...          ...         ...         ...         ...         ...        ...
# 1254  2022-11-07   72.790001   69.870003   70.370003   72.279999  3551800.0
# 1255  2022-11-08   72.720001   68.980003   72.489998   70.419998  3600900.0
# 1256  2022-11-09   70.269997   67.970001   69.489998   68.279999  4201200.0
# 1257  2022-11-10   74.129997   71.419998   71.959999   72.000000  4894700.0
# 1258  2022-11-11   78.830002   74.760002   75.000000   77.980003  6393300.0
#
#        Adj Close
# 0     145.725998
# 1     144.186523
# ...

# %%
df3['Close']-df3['Adj Close']
# Out:
# 0       9.514008
# 1       9.413483
# 2       8.827332
# 3       8.919312
# 4       8.865768
#           ...
# 1254    0.000000
# 1255    0.000000
# 1256    0.000000
# 1257    0.000000
# 1258    0.000000
# Length: 1259, dtype: float64

# %%
# financial point of view: no dividends are paid to the shareholders as adj close price considers all applicable 
# splits and dividend distributions.

# %%
#2

# %%
#EQR

# %%
df['Adj Close'].max()
# Out:
# 93.23999786376952

# %%
df['Adj Close'].min()
# Out:
# 44.40938949584961

# %%
# JKHY

# %%
df2['Adj Close'].max()
# Out:
# 211.07000732421875

# %%
df2['Adj Close'].min()
# Out:
# 107.51292419433594

# %%
# WYNN

# %%
df3['Adj Close'].max()
# Out:
# 190.3560943603516

# %%
df3['Adj Close'].min()
# Out:
# 43.02000045776367

# %%
#3

# %%
df['Adj Close'].shift(1)
# Out:
# 0             NaN
# 1       60.831173
# 2       60.683773
# 3       59.859966
# 4       60.024731
#           ...
# 1254    61.259998
# 1255    60.189999
# 1256    60.060001
# 1257    59.680000
# 1258    63.970001
# Name: Adj Close, Length: 1259, dtype: float64

# %%
log1 = np.log(df['Adj Close']/df['Adj Close'].shift(1))
log1.describe()
# Out:
# count    1258.000000
# mean        0.000025
# std         0.018368
# min        -0.185287
# 25%        -0.008015
# 50%         0.000599
# 75%         0.008373
# max         0.140302
# Name: Adj Close, dtype: float64

# %%
log2 = np.log(df2['Adj Close']/df2['Adj Close'].shift(1))
log2.describe()
# Out:
# count    1257.000000
# mean        0.000380
# std         0.016325
# min        -0.137826
# 25%        -0.007359
# 50%         0.001308
# 75%         0.008689
# max         0.092916
# Name: Adj Close, dtype: float64

# %%
log3 = np.log(df3['Adj Close']/df3['Adj Close'].shift(1))
log3.describe()
# Out:
# count    1258.000000
# mean       -0.000497
# std         0.035827
# min        -0.280172
# 25%        -0.017554
# 50%        -0.000936
# 75%         0.016293
# max         0.244422
# Name: Adj Close, dtype: float64

# %%
#7

# %%
a = log1
b = log2
c = log3

# %%
plt.figure(figsize=(10, 6))

plt.plot(df['Date'], a, label = 'log_return, EQR')
plt.plot(df2['Date'], b, label = 'log_return, JKHY')
plt.plot(df3['Date'], c, label = 'log_return, WYNN')
plt.legend()

# %%
# Part 2

# %%
#1

# %%
dff = pd.read_csv('https://ies-python-midterm.s3.eu-central-1.amazonaws.com/companies/companies_no_subindustry.csv')
dff
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4     ABMD               Abiomed             Health Care
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                           hq    included      Founded
# 0      Saint Paul, Minnesota  09.08.1976         1902
# 1       Milwaukee, Wisconsin  26.07.2017         1916
# 2    North Chicago, Illinois  31.03.1964         1888
# 3    North Chicago, Illinois  31.12.2012  2013 (1888)
# ...

# %%
dff.columns
# Out:
# Index(['Symbol', 'Security', 'GICS Sector', 'hq', 'included', 'Founded'], dtype='object')

# %%
dff['included'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 498    False
# 499    False
# 500    False
# 501    False
# 502    False
# Name: included, Length: 503, dtype: bool

# %%
dff[dff['included'].isnull()].count()
#missing values: 45
# Out:
# Symbol         45
# Security       45
# GICS Sector    45
# hq             45
# included        0
# Founded        45
# dtype: int64

# %%
#2

# %%
dff2 = dff.dropna()
dff2
dff2[dff2['included'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Symbol, Security, GICS Sector, hq, included, Founded]
# Index: []

# %%
#3

# %%
group = dff2.groupby(dff2['GICS\xa0Sector'])
group.describe()
# Out:
#                        Symbol                   Security         \
#                         count unique   top freq    count unique
# GICS Sector
# Communication Services     23     23  ATVI    1       23     23
# Consumer Discretionary     52     52   AAP    1       52     52
# Consumer Staples           33     33   ADM    1       33     33
# Energy                     22     22   APA    1       22     22
# Financials                 55     55   AFL    1       55     55
# Health Care                60     60   ABT    1       60     60
# Industrials                66     66   MMM    1       66     66
# Information Technology     68     68   ACN    1       68     68
# Materials                  26     26   APD    1       26     26
# Real Estate                30     30   ARE    1       30     30
# Utilities                  23     23   AES    1       23     23
#
#                                                                 hq         \
# ...

# %%
result = group['Symbol'].count()
result
# Out:
# GICS Sector
# Communication Services    23
# Consumer Discretionary    52
# Consumer Staples          33
# Energy                    22
# Financials                55
# Health Care               60
# Industrials               66
# Information Technology    68
# Materials                 26
# Real Estate               30
# Utilities                 23
# Name: Symbol, dtype: int64

# %%
plt.figure(figsize = (7,7)) 
plt.pie(result, labels = result.index, autopct = "%.1f %%")
plt.show()

# %%
#4

# %%
dff2
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4     ABMD               Abiomed             Health Care
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                           hq    included      Founded
# 0      Saint Paul, Minnesota  09.08.1976         1902
# 1       Milwaukee, Wisconsin  26.07.2017         1916
# 2    North Chicago, Illinois  31.03.1964         1888
# 3    North Chicago, Illinois  31.12.2012  2013 (1888)
# ...

# %%
dff2['state'] = dff2.hq.apply(lambda hq: hq.split()[1])
dff2
# Out:
# /var/folders/l3/c5zzhv052yg1_z3b20tfwdpm0000gn/T/ipykernel_47762/844619166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff2['state'] = dff2.hq.apply(lambda hq: hq.split()[1])
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4     ABMD               Abiomed             Health Care
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# ...

# %%
dff2['state'].describe()
# Out:
# count       458
# unique       96
# top       Texas
# freq         40
# Name: state, dtype: object

# %%
#5

# %%
dff3 = pd.read_csv('https://ies-python-midterm.s3.eu-central-1.amazonaws.com/companies/companies_subindustry.csv')
dff3
# Out:
#     Symbol                         subindustry
# 0      MMM            Industrial Conglomerates
# 1      AOS                   Building Products
# 2      ABT               Health Care Equipment
# 3     ABBV                     Pharmaceuticals
# 4     ABMD               Health Care Equipment
# ..     ...                                 ...
# 498    YUM                         Restaurants
# 499   ZBRA  Electronic Equipment & Instruments
# 500    ZBH               Health Care Equipment
# 501   ZION                      Regional Banks
# 502    ZTS                     Pharmaceuticals
#
# [503 rows x 2 columns]

# %%
dff4 = pd.merge(dff2, dff3, on = "Symbol")
dff4
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4     ABMD               Abiomed             Health Care
# ..     ...                   ...                     ...
# 453    YUM           Yum! Brands  Consumer Discretionary
# 454   ZBRA    Zebra Technologies  Information Technology
# 455    ZBH         Zimmer Biomet             Health Care
# 456   ZION  Zions Bancorporation              Financials
# 457    ZTS                Zoetis             Health Care
#
#                           hq    included      Founded          state  \
# 0      Saint Paul, Minnesota  09.08.1976         1902          Paul,
# 1       Milwaukee, Wisconsin  26.07.2017         1916      Wisconsin
# 2    North Chicago, Illinois  31.03.1964         1888       Chicago,
# ...

# %%
dff4[dff4['GICS\xa0Sector'] == 'Consumer Discretionary'].describe()
# Out:
#        Symbol            Security             GICS Sector                hq  \
# count      52                  52                      52                52
# unique     52                  52                       1                41
# top       AAP  Advance Auto Parts  Consumer Discretionary  Atlanta, Georgia
# freq        1                   1                      52                 4
#
#           included Founded    state       subindustry
# count           52      52       52                52
# unique          51      44       30                19
# top     19.12.2011    1993  Georgia  Specialty Stores
# freq             2       3        5                 6
